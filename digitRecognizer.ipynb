# %% [markdown]
# A CNN model is created and trained on the char54k dataset to identify digits 1 to 9

# %%
def getBestShift(img): #function to calculate the COM shift
    cy,cx = ndimage.measurements.center_of_mass(img)
    rows,cols = img.shape
    shiftx = numpy.round(cols/2.0-cx).astype(int)
    shifty = numpy.round(rows/2.0-cy).astype(int)
    return shiftx,shifty

# %%
def createTrainingData(): #function is used to read image traning data from the folders named 1, 2,..., 9 in the DigitImages directory
    for category in CATEGORIES:
        path = os.path.join(DATADIR, category)
        class_num = CATEGORIES.index(category)
        for img in os.listdir(path):
            img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
            new_array = cv2.resize(img_array, (img_rows, img_cols))
            new_array = shiftCenterOfMass(new_array)
            training_data.append([new_array, class_num])

# %%
#This function will centralize the image according to its center of mass.Same has been implemented in sudokuSolver. Without this step, the accuracy drops from nearly 100% to 70-80%
def shiftCenterOfMass(img):
    img = cv2.bitwise_not(img)

    # Centralize the image according to center of mass
    shiftx,shifty = getBestShift(img)
    shifted = shift(img,shiftx,shifty)
    img = shifted

    img = cv2.bitwise_not(img)
    return img

# %%
#function to shift image
def shift(img,sx,sy):
    rows,cols = img.shape
    M = numpy.float32([[1,0,sx],[0,1,sy]])
    shifted = cv2.warpAffine(img,M,(cols,rows))
    return shifted

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.utils import to_categorical


import numpy
import os
import random
import cv2
from scipy import ndimage

# %%
batch_size = 128
num_classes = 9
epochs = 45

# input image dimensions
img_rows, img_cols = 28, 28

DATADIR = "DigitImages"
CATEGORIES = ["1","2","3","4","5","6","7","8","9"]

training_data = []

createTrainingData()

# Mix data up
random.shuffle(training_data)

# Split 80-20
x_train = []
y_train = []
x_test = []
y_test = []
for i in range(len(training_data)*8//10):
    x_train.append(training_data[i][0])
    y_train.append(training_data[i][1])
for i in range(len(training_data)*8//10,len(training_data)):
    x_test.append(training_data[i][0])
    y_test.append(training_data[i][1])

# Reshape
x_train = numpy.array(x_train)
x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
x_test = numpy.array(x_test)
x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# Normalize the data
x_train /= 255
x_test /= 255

# convert class vectors to binary class matrices
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),activation='relu',input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=tf.keras.losses.categorical_crossentropy,optimizer="Adam",metrics=['accuracy'])

model.fit(x_train, y_train,batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(x_test, y_test))

score = model.evaluate(x_test, y_test, verbose=0)

print('Test loss:', score[0])
print('Test accuracy:', score[1])

model.save_weights('digitRecognition.h5')
# Out:
# C:\Users\Rohan kumar\AppData\Local\Temp\ipykernel_27456\1808188631.py:2: DeprecationWarning: Please use `center_of_mass` from the `scipy.ndimage` namespace, the `scipy.ndimage.measurements` namespace is deprecated.
#   cy,cx = ndimage.measurements.center_of_mass(img)
# WARNING:tensorflow:From C:\Users\Rohan kumar\AppData\Roaming\Python\Python311\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Rohan kumar\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\Rohan kumar\AppData\Roaming\Python\Python311\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/45
# WARNING:tensorflow:From C:\Users\Rohan kumar\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Rohan kumar\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 58/58 [==============================] - 28s 388ms/step - loss: 0.7769 - accuracy: 0.7699 - val_loss: 0.1797 - val_accuracy: 0.9448
# Epoch 2/45
# 58/58 [==============================] - 25s 429ms/step - loss: 0.2112 - accuracy: 0.9374 - val_loss: 0.1109 - val_accuracy: 0.9645
# Epoch 3/45
# 58/58 [==============================] - 22s 377ms/step - loss: 0.1197 - accuracy: 0.9647 - val_loss: 0.0700 - val_accuracy: 0.9765
# Epoch 4/45
# 58/58 [==============================] - 23s 398ms/step - loss: 0.0835 - accuracy: 0.9748 - val_loss: 0.0518 - val_accuracy: 0.9809
# Epoch 5/45
# 58/58 [==============================] - 23s 396ms/step - loss: 0.0621 - accuracy: 0.9814 - val_loss: 0.0409 - val_accuracy: 0.9852
# Epoch 6/45
# 58/58 [==============================] - 19s 326ms/step - loss: 0.0466 - accuracy: 0.9856 - val_loss: 0.0298 - val_accuracy: 0.9891
# Epoch 7/45
# 58/58 [==============================] - 19s 323ms/step - loss: 0.0401 - accuracy: 0.9880 - val_loss: 0.0306 - val_accuracy: 0.9880
# Epoch 8/45
# 58/58 [==============================] - 19s 320ms/step - loss: 0.0348 - accuracy: 0.9885 - val_loss: 0.0261 - val_accuracy: 0.9907
# Epoch 9/45
# 58/58 [==============================] - 21s 365ms/step - loss: 0.0330 - accuracy: 0.9895 - val_loss: 0.0264 - val_accuracy: 0.9913
# Epoch 10/45
# 58/58 [==============================] - 20s 346ms/step - loss: 0.0290 - accuracy: 0.9911 - val_loss: 0.0221 - val_accuracy: 0.9918
# Epoch 11/45
# 58/58 [==============================] - 20s 344ms/step - loss: 0.0229 - accuracy: 0.9928 - val_loss: 0.0193 - val_accuracy: 0.9918
# Epoch 12/45
# 58/58 [==============================] - 21s 358ms/step - loss: 0.0176 - accuracy: 0.9941 - val_loss: 0.0278 - val_accuracy: 0.9896
# Epoch 13/45
# 58/58 [==============================] - 24s 412ms/step - loss: 0.0169 - accuracy: 0.9947 - val_loss: 0.0155 - val_accuracy: 0.9945
# Epoch 14/45
# 58/58 [==============================] - 22s 378ms/step - loss: 0.0153 - accuracy: 0.9956 - val_loss: 0.0247 - val_accuracy: 0.9907
# Epoch 15/45
# 58/58 [==============================] - 20s 351ms/step - loss: 0.0119 - accuracy: 0.9964 - val_loss: 0.0226 - val_accuracy: 0.9923
# Epoch 16/45
# 58/58 [==============================] - 24s 417ms/step - loss: 0.0139 - accuracy: 0.9958 - val_loss: 0.0171 - val_accuracy: 0.9929
# Epoch 17/45
# 58/58 [==============================] - 2463s 43s/step - loss: 0.0124 - accuracy: 0.9962 - val_loss: 0.0185 - val_accuracy: 0.9951
# Epoch 18/45
# 58/58 [==============================] - 20s 338ms/step - loss: 0.0159 - accuracy: 0.9958 - val_loss: 0.0194 - val_accuracy: 0.9923
# Epoch 19/45
# 58/58 [==============================] - 20s 337ms/step - loss: 0.0154 - accuracy: 0.9944 - val_loss: 0.0176 - val_accuracy: 0.9929
# Epoch 20/45
# 58/58 [==============================] - 20s 350ms/step - loss: 0.0119 - accuracy: 0.9962 - val_loss: 0.0185 - val_accuracy: 0.9923
# Epoch 21/45
# 58/58 [==============================] - 18s 309ms/step - loss: 0.0100 - accuracy: 0.9973 - val_loss: 0.0198 - val_accuracy: 0.9934
# Epoch 22/45
# 58/58 [==============================] - 17s 290ms/step - loss: 0.0084 - accuracy: 0.9981 - val_loss: 0.0175 - val_accuracy: 0.9929
# Epoch 23/45
# 58/58 [==============================] - 18s 305ms/step - loss: 0.0160 - accuracy: 0.9937 - val_loss: 0.0201 - val_accuracy: 0.9918
# Epoch 24/45
# 58/58 [==============================] - 16s 273ms/step - loss: 0.0093 - accuracy: 0.9974 - val_loss: 0.0134 - val_accuracy: 0.9934
# Epoch 25/45
# 58/58 [==============================] - 17s 298ms/step - loss: 0.0092 - accuracy: 0.9975 - val_loss: 0.0142 - val_accuracy: 0.9945
# Epoch 26/45
# 58/58 [==============================] - 17s 297ms/step - loss: 0.0069 - accuracy: 0.9977 - val_loss: 0.0113 - val_accuracy: 0.9945
# Epoch 27/45
# 58/58 [==============================] - 17s 284ms/step - loss: 0.0071 - accuracy: 0.9974 - val_loss: 0.0134 - val_accuracy: 0.9956
# Epoch 28/45
# 58/58 [==============================] - 17s 292ms/step - loss: 0.0077 - accuracy: 0.9971 - val_loss: 0.0142 - val_accuracy: 0.9945
# Epoch 29/45
# 58/58 [==============================] - 19s 326ms/step - loss: 0.0067 - accuracy: 0.9984 - val_loss: 0.0132 - val_accuracy: 0.9934
# Epoch 30/45
# 58/58 [==============================] - 18s 312ms/step - loss: 0.0063 - accuracy: 0.9982 - val_loss: 0.0156 - val_accuracy: 0.9934
# Epoch 31/45
# 58/58 [==============================] - 20s 340ms/step - loss: 0.0108 - accuracy: 0.9967 - val_loss: 0.0212 - val_accuracy: 0.9934
# Epoch 32/45
# 58/58 [==============================] - 16s 275ms/step - loss: 0.0086 - accuracy: 0.9973 - val_loss: 0.0147 - val_accuracy: 0.9929
# Epoch 33/45
# 58/58 [==============================] - 16s 278ms/step - loss: 0.0068 - accuracy: 0.9981 - val_loss: 0.0154 - val_accuracy: 0.9929
# Epoch 34/45
# 58/58 [==============================] - 17s 287ms/step - loss: 0.0074 - accuracy: 0.9979 - val_loss: 0.0196 - val_accuracy: 0.9923
# Epoch 35/45
# 58/58 [==============================] - 19s 330ms/step - loss: 0.0070 - accuracy: 0.9978 - val_loss: 0.0182 - val_accuracy: 0.9918
# Epoch 36/45
# 58/58 [==============================] - 18s 305ms/step - loss: 0.0079 - accuracy: 0.9974 - val_loss: 0.0193 - val_accuracy: 0.9923
# Epoch 37/45
# 58/58 [==============================] - 16s 279ms/step - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.0181 - val_accuracy: 0.9929
# Epoch 38/45
# 58/58 [==============================] - 17s 291ms/step - loss: 0.0054 - accuracy: 0.9985 - val_loss: 0.0248 - val_accuracy: 0.9918
# Epoch 39/45
# 58/58 [==============================] - 16s 270ms/step - loss: 0.0037 - accuracy: 0.9989 - val_loss: 0.0202 - val_accuracy: 0.9929
# Epoch 40/45
# 58/58 [==============================] - 16s 277ms/step - loss: 0.0057 - accuracy: 0.9981 - val_loss: 0.0178 - val_accuracy: 0.9934
# Epoch 41/45
# 58/58 [==============================] - 19s 329ms/step - loss: 0.0063 - accuracy: 0.9984 - val_loss: 0.0223 - val_accuracy: 0.9929
# Epoch 42/45
# 58/58 [==============================] - 26s 448ms/step - loss: 0.0062 - accuracy: 0.9977 - val_loss: 0.0251 - val_accuracy: 0.9913
# Epoch 43/45
# 58/58 [==============================] - 21s 368ms/step - loss: 0.0058 - accuracy: 0.9974 - val_loss: 0.0182 - val_accuracy: 0.9913
# Epoch 44/45
# 58/58 [==============================] - 18s 308ms/step - loss: 0.0081 - accuracy: 0.9974 - val_loss: 0.0121 - val_accuracy: 0.9945
# Epoch 45/45
# 58/58 [==============================] - 19s 324ms/step - loss: 0.0075 - accuracy: 0.9975 - val_loss: 0.0139 - val_accuracy: 0.9951
# Test loss: 0.01385931484401226
# Test accuracy: 0.9950792789459229
